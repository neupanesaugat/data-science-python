# %%
import pandas as pd

# %%
#Create a dictionary
data={
"names":["Bill","Tom","Tim","John","Alex","Vanessa","Kate","Smarika"],
"score":[90,80,85,75,95,60,65,32],
"sport":["Wrestling","Football","Skiing","Swimming","Tennis","Karate","Surfing","Studying"],
"sex":['M','M','M','M','F','F','F','O']
}

# %%
data
# Out:
# {'names': ['Bill', 'Tom', 'Tim', 'John', 'Alex', 'Vanessa', 'Kate'],
#  'score': [90, 80, 85, 75, 95, 60, 65],
#  'sport': ['Wrestling',
#   'Football',
#   'Skiing',
#   'Swimming',
#   'Tennis',
#   'Karate',
#   'Surfing'],
#  'sex': ['M', 'M', 'M', 'M', 'F', 'F', 'F']}

# %%
type(data)
# Out:
# dict

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#      names  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karate   F
# 6     Kate     65    Surfing   F

# %%
type(df
    )
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail()
# Out:
#      names  score     sport sex
# 2      Tim     85    Skiing   M
# 3     John     75  Swimming   M
# 4     Alex     95    Tennis   F
# 5  Vanessa     60    Karate   F
# 6     Kate     65   Surfing   F

# %%
df.head()
# Out:
#   names  score      sport sex
# 0  Bill     90  Wrestling   M
# 1   Tom     80   Football   M
# 2   Tim     85     Skiing   M
# 3  John     75   Swimming   M
# 4  Alex     95     Tennis   F

# %%
df= pd.DataFrame(data, columns= ["Name","Sport","Gender","Score","Age"])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Name, Sport, Gender, Score, Age]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [Name, Sport, Gender, Score, Age]
# Index: []

# %%
data
# Out:
# {'names': ['Bill', 'Tom', 'Tim', 'John', 'Alex', 'Vanessa', 'Kate'],
#  'score': [90, 80, 85, 75, 95, 60, 65],
#  'sport': ['Wrestling',
#   'Football',
#   'Skiing',
#   'Swimming',
#   'Tennis',
#   'Karate',
#   'Surfing'],
#  'sex': ['M', 'M', 'M', 'M', 'F', 'F', 'F']}

# %%
df
# Out:
# Empty DataFrame
# Columns: [Name, Sport, Gender, Score, Age]
# Index: []

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#      names  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karate   F
# 6     Kate     65    Surfing   F

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#      names  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karate   F
# 6     Kate     65    Surfing   F

# %%
df= pd.DataFrame(data, columns= ["names","score","sport","sex","Age"])

# %%
df
# Out:
#      names  score      sport sex  Age
# 0     Bill     90  Wrestling   M  NaN
# 1      Tom     80   Football   M  NaN
# 2      Tim     85     Skiing   M  NaN
# 3     John     75   Swimming   M  NaN
# 4     Alex     95     Tennis   F  NaN
# 5  Vanessa     60     Karate   F  NaN
# 6     Kate     65    Surfing   F  NaN

# %%
df= pd.DataFrame(data, columns= ["names","score","sport","sex","Age"],index=["Kaa","Kha","Ga","Gha","Ma","Da","Fa","Ka"])

# %%
df
# Out:
#        names  score      sport sex  Age
# Kaa     Bill     90  Wrestling   M  NaN
# Kha      Tom     80   Football   M  NaN
# Ga       Tim     85     Skiing   M  NaN
# Gha     John     75   Swimming   M  NaN
# Ma      Alex     95     Tennis   F  NaN
# Da   Vanessa     60     Karate   F  NaN
# Fa      Kate     65    Surfing   F  NaN
# Ka   Smarika     32   Studying   O  NaN

# %%
df.loc['Ka']
# Out:
#       names  score      sport sex  Age
# Ka     Bill     90  Wrestling   M  NaN
# Ka  Smarika     32   Studying   O  NaN

# %%
df.loc['Ka']
# Out:
# names     Smarika
# score          32
# sport    Studying
# sex             O
# Age           NaN
# Name: Ka, dtype: object

# %%
df.iloc['Ka']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df.iloc['Ka']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1622, in _iLocIndexer._getitem_axis(self, key, axis)
#    1620 key = item_from_zerodim(key)
#    1621 if not is_integer(key):
# -> 1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
#    1625 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
df['Age']=18

# %%
df
# Out:
#        names  score      sport sex  Age
# Kaa     Bill     90  Wrestling   M   18
# Kha      Tom     80   Football   M   18
# Ga       Tim     85     Skiing   M   18
# Gha     John     75   Swimming   M   18
# Ma      Alex     95     Tennis   F   18
# Da   Vanessa     60     Karate   F   18
# Fa      Kate     65    Surfing   F   18
# Ka   Smarika     32   Studying   O   18

# %%
values= [18,19,20,21,17,36,45,69]
df["Age"]=values

# %%
df
# Out:
#        names  score      sport sex  Age
# Kaa     Bill     90  Wrestling   M   18
# Kha      Tom     80   Football   M   19
# Ga       Tim     85     Skiing   M   20
# Gha     John     75   Swimming   M   21
# Ma      Alex     95     Tennis   F   17
# Da   Vanessa     60     Karate   F   36
# Fa      Kate     65    Surfing   F   45
# Ka   Smarika     32   Studying   O   69

# %%
df= pd.DataFrame(df, columns= ["names","score","sport","sex","Age","pass"])

# %%
df
# Out:
#        names  score      sport sex  Age  pass
# Kaa     Bill     90  Wrestling   M   18  True
# Kha      Tom     80   Football   M   19  True
# Ga       Tim     85     Skiing   M   20  True
# Gha     John     75   Swimming   M   21  True
# Ma      Alex     95     Tennis   F   17  True
# Da   Vanessa     60     Karate   F   36  True
# Fa      Kate     65    Surfing   F   45  True
# Ka   Smarika     32   Studying   O   69  True

# %%
df["pass"]=df.score>=32

# %%
df
# Out:
#        names  score      sport sex  Age  pass
# Kaa     Bill     90  Wrestling   M   18  True
# Kha      Tom     80   Football   M   19  True
# Ga       Tim     85     Skiing   M   20  True
# Gha     John     75   Swimming   M   21  True
# Ma      Alex     95     Tennis   F   17  True
# Da   Vanessa     60     Karate   F   36  True
# Fa      Kate     65    Surfing   F   45  True
# Ka   Smarika     32   Studying   O   69  True

# %%
del df["pass"]

# %%
df
# Out:
#        names  score      sport sex  Age
# Kaa     Bill     90  Wrestling   M   18
# Kha      Tom     80   Football   M   19
# Ga       Tim     85     Skiing   M   20
# Gha     John     75   Swimming   M   21
# Ma      Alex     95     Tennis   F   17
# Da   Vanessa     60     Karate   F   36
# Fa      Kate     65    Surfing   F   45
# Ka   Smarika     32   Studying   O   69
