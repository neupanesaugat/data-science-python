# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
plt.style.use("ggplot") #not mandatory

# %%
data = pd.Series(np.random.randn(1000).cumsum())
data
# Out:
# 0      -0.194527
# 1      -0.030017
# 2       0.308034
# 3       1.545327
# 4       1.261725
#          ...
# 995    18.233058
# 996    18.070100
# 997    17.148311
# 998    17.524676
# 999    16.581605
# Length: 1000, dtype: float64

# %%
data.plot()
# Out:
# <Axes: >

# %%
df1 = pd.DataFrame(np.random.randn(1000,4),
                    columns = list("ABCD"))
df1.head()
# Out:
#           A         B         C         D
# 0  0.093558  1.543020  1.254730 -0.085423
# 1 -1.395034 -1.788954 -0.892823 -1.074842
# 2 -1.907118 -0.725174 -1.183999 -0.577444
# 3 -0.511798  1.700324  1.574008 -1.121729
# 4 -0.773125  2.915188  1.118421  0.261474

# %%
df1 = df1.cumsum()
df1
# Out:
#              A          B          C         D
# 0     0.093558   1.543020   1.254730 -0.085423
# 1    -1.301476  -0.245933   0.361908 -1.160266
# 2    -3.208594  -0.971107  -0.822091 -1.737710
# 3    -3.720392   0.729217   0.751917 -2.859439
# 4    -4.493518   3.644406   1.870338 -2.597965
# ..         ...        ...        ...       ...
# 995  23.102423 -92.363518 -53.699914  5.968177
# 996  23.703633 -91.782256 -54.543648  5.012530
# 997  23.130569 -91.329376 -54.569435  4.154834
# 998  23.229140 -89.805549 -55.445985  3.020289
# 999  21.482413 -89.096930 -55.401674  4.425595
#
# [1000 rows x 4 columns]

# %%
df1.plot()
# Out:
# <Axes: >

# %%
#Bar plot of the 10th data
df1.iloc[10].plot(kind="bar")
# Out:
# <Axes: >

# %%
df1.iloc[10].plot.bar(color = "green")
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(np.random.randn(7,3),
                  columns = list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0  1.062116  1.811099  1.358231
# 1  0.030658  1.209474 -0.816016
# 2 -0.998993 -0.937429 -0.996236
# 3  0.322652  0.355883 -0.280045
# 4  0.951503 -0.115954 -1.360419
# 5 -0.389131 -1.795599 -0.432739
# 6 -0.207721 -0.029402 -0.300636

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
#Stacked Bar Chart
df2.plot.bar(stacked = True)
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked = True, orientation = "horizontal")
# Out:
# <Axes: >

# %%
iris = pd.read_csv("iris.data", header = None)

# %%
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.columns = ["sepal_length","sepal_width","petal_length","petal_width","class"]
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.plot.hist(alpha = 0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha = 0.5, stacked = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha =1, stacked = True, bins = 25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha =1, stacked = True, bins = 25, orientation = 'horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris["sepal_width"].plot.hist(alpha = 0.5, stacked = True, orientation = "horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris["sepal_length"].diff().hist()
# Out:
# <Axes: >

# %%
iris.hist(alpha = 0.5, color = 'red', bins=20)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.hist("petal_length", by = 'class')
# Out:
# array([[<Axes: title={'center': 'Iris-setosa'}>,
#         <Axes: title={'center': 'Iris-versicolor'}>],
#        [<Axes: title={'center': 'Iris-virginica'}>, <Axes: >]],
#       dtype=object)

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
colors = {'boxes': 'Red', 'whiskers': 'blue', 'medians':'black', 'caps':'green'}
iris.plot.box(color = colors)
# Out:
# <Axes: >

# %%
iris.plot.box(vert = False)
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"] = [8,8]
plt.style.use("ggplot")
iris.boxplot(by='class')
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[class]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[class]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[class]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[class]'>]],
#       dtype=object)

# %% [markdown]
# AREA CHART

# %%
df = pd.DataFrame(np.random.rand(10,4),columns = list("ABCD"))
df
# Out:
#           A         B         C         D
# 0  0.303307  0.700872  0.551351  0.945435
# 1  0.065639  0.458076  0.384177  0.332614
# 2  0.033451  0.123904  0.182874  0.272526
# 3  0.096689  0.082317  0.279685  0.043032
# 4  0.210294  0.601106  0.371028  0.175714
# 5  0.792126  0.304473  0.700416  0.402193
# 6  0.640635  0.786104  0.461049  0.851784
# 7  0.911046  0.369847  0.462653  0.712488
# 8  0.822055  0.410847  0.296855  0.081462
# 9  0.976521  0.265068  0.978418  0.693112

# %%
df["A"].plot.area()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.area(stacked = False)
# Out:
# <Axes: >

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.plot.area()
# Out:
# <Axes: >

# %%
iris.plot.area(stacked=False)
# Out:
# <Axes: >

# %% [markdown]
# SCATTER PLOTS

# %%
df.plot.scatter(x = "A", y = "B")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
movies = pd.read_csv("imdbratings.txt")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.plot.scatter(x ="star_rating", y= "duration")
# Out:
# <Axes: xlabel='star_rating', ylabel='duration'>

# %%
ax = iris.plot.scatter(x ="sepal_length", y= "sepal_width", color = 'blue', label = 'sepal')
ax
iris.plot.scatter(x ="petal_length", y= "petal_width", color = 'red', label = 'petal',ax = ax)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
iris.plot.scatter(x ="sepal_length", y= "sepal_width", c= "petal_length", s=100)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.scatter(x ="sepal_length", y= "sepal_width", s=iris["petal_length"]*50)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
movies.plot.hexbin(x= "star_rating", y = "duration", gridsize =15)
# Out:
# <Axes: xlabel='star_rating', ylabel='duration'>

# %% [markdown]
# MAKING PIE CHART

# %%
iris_avg = iris["petal_width"].groupby(iris["class"]).mean()

# %%
iris_avg
# Out:
# class
# Iris-setosa        0.244
# Iris-versicolor    1.326
# Iris-virginica     2.026
# Name: petal_width, dtype: float64

# %%
iris_avg.plot.pie()
# Out:
# <Axes: ylabel='petal_width'>

# %%
iris_avg1 = iris[["petal_width","petal_length"]].groupby(iris["class"]).mean()

# %%
iris_avg1
# Out:
#                  petal_width  petal_length
# class
# Iris-setosa            0.244         1.464
# Iris-versicolor        1.326         4.260
# Iris-virginica         2.026         5.552

# %%
iris_avg1.plot.pie(subplots = True)
# Out:
# array([<Axes: ylabel='petal_width'>, <Axes: ylabel='petal_length'>],
#       dtype=object)

# %%
iris_avg.plot.pie(labels = ["setosa","versicolor","virginica"],
                 colors = list("brg"), fontsize = 25, figsize=(10,10))
# Out:
# <Axes: ylabel='petal_width'>

# %%
iris_avg.plot.pie(labels = ["setosa","versicolor","virginica"],
                 colors = list("rgb"), fontsize = 25, figsize=(10,10),autopct = '%.2f')
# Out:
# <Axes: ylabel='petal_width'>

# %% [markdown]
# DENSITY CHART (KDE CHART)

# %%
iris.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
#MAKING SCATTER MATRIX
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(movies , alpha = 0.7, diagonal = 'kde')
# Out:
# array([[<Axes: xlabel='star_rating', ylabel='star_rating'>,
#         <Axes: xlabel='duration', ylabel='star_rating'>],
#        [<Axes: xlabel='star_rating', ylabel='duration'>,
#         <Axes: xlabel='duration', ylabel='duration'>]], dtype=object)
